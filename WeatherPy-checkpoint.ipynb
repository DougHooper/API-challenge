# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
weather_api_key = "4cd9ccedff156f0de3143ba431958a6a"

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
base_URL = f"{url}appid={weather_api_key}&units={units}&q="
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_URL}{city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather ['coord']['lon']
        city_max_temp = city_weather ['main']['temp_max']
        city_humidity = city_weather ['main']['humidity']
        city_clouds = city_weather ['clouds']['all']
        city_wind = city_weather ['wind']['speed']
        city_country = city_weather ['sys']['country']
        city_date = city_weather ['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port mathurin
# Processing Record 2 of Set 1 | kargasok
# Processing Record 3 of Set 1 | constantia
# Processing Record 4 of Set 1 | meulaboh
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | kidal
# Processing Record 10 of Set 1 | blackmans bay
# Processing Record 11 of Set 1 | puerto natales
# Processing Record 12 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | woolgoolga
# Processing Record 15 of Set 1 | jertih
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | fort mcmurray
# Processing Record 18 of Set 1 | roma
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | ust-nera
# Processing Record 21 of Set 1 | jalai nur
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | invercargill
# Processing Record 24 of Set 1 | borazjan
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | bardai
# Processing Record 27 of Set 1 | tobruk
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | piriapolis
# Processing Record 30 of Set 1 | aykhal
# Processing Record 31 of Set 1 | urangan
# Processing Record 32 of Set 1 | oualidia
# City not found. Skipping...
# Processing Record 33 of Set 1 | zhezqazghan
# Processing Record 34 of Set 1 | le robert
# Processing Record 35 of Set 1 | taraz
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | edinburgh of the seven seas
# Processing Record 38 of Set 1 | iskateley
# Processing Record 39 of Set 1 | olonkinbyen
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | zvishavane
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | papatowai
# Processing Record 47 of Set 1 | broome
# Processing Record 48 of Set 1 | kalkaman
# Processing Record 49 of Set 1 | miasskoye
# Processing Record 50 of Set 1 | tambuwal
# Processing Record 0 of Set 2 | bubaque
# Processing Record 1 of Set 2 | azul
# Processing Record 2 of Set 2 | anadyr
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | usinsk
# Processing Record 5 of Set 2 | stanley
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | borca
# Processing Record 9 of Set 2 | verkhnevilyuysk
# Processing Record 10 of Set 2 | santa cruz
# Processing Record 11 of Set 2 | dryden
# Processing Record 12 of Set 2 | tachilek
# City not found. Skipping...
# Processing Record 13 of Set 2 | fortuna
# Processing Record 14 of Set 2 | armacao de buzios
# Processing Record 15 of Set 2 | quibala
# Processing Record 16 of Set 2 | khash
# Processing Record 17 of Set 2 | bouna
# Processing Record 18 of Set 2 | badger
# Processing Record 19 of Set 2 | timra
# Processing Record 20 of Set 2 | west island
# Processing Record 21 of Set 2 | pimentel
# Processing Record 22 of Set 2 | mohale's hoek
# Processing Record 23 of Set 2 | itaberaba
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | klyuchi
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | lompoc
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | bonthe
# Processing Record 30 of Set 2 | saint-pierre
# Processing Record 31 of Set 2 | qaqortoq
# Processing Record 32 of Set 2 | upata
# Processing Record 33 of Set 2 | kailua-kona
# Processing Record 34 of Set 2 | maragogi
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | kuala belait
# Processing Record 39 of Set 2 | northam
# Processing Record 40 of Set 2 | nova londrina
# Processing Record 41 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 42 of Set 2 | tyre
# Processing Record 43 of Set 2 | mermoz boabab
# Processing Record 44 of Set 2 | hinton
# Processing Record 45 of Set 2 | villa gesell
# Processing Record 46 of Set 2 | colonia
# Processing Record 47 of Set 2 | bratsk
# Processing Record 48 of Set 2 | awjilah
# Processing Record 49 of Set 2 | labytnangi
# Processing Record 0 of Set 3 | lihue
# Processing Record 1 of Set 3 | belozersk
# Processing Record 2 of Set 3 | igarka
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | gonabad
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | toliara
# Processing Record 7 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 8 of Set 3 | opochka
# Processing Record 9 of Set 3 | vilyuchinsk
# Processing Record 10 of Set 3 | enewetak
# Processing Record 11 of Set 3 | bel ombre
# Processing Record 12 of Set 3 | ercis
# Processing Record 13 of Set 3 | hamilton
# Processing Record 14 of Set 3 | linqu
# Processing Record 15 of Set 3 | ma'an
# Processing Record 16 of Set 3 | coquimbo
# Processing Record 17 of Set 3 | lashio
# Processing Record 18 of Set 3 | red bluff
# Processing Record 19 of Set 3 | tazovsky
# Processing Record 20 of Set 3 | arafat
# Processing Record 21 of Set 3 | moose jaw
# Processing Record 22 of Set 3 | tomatlan
# Processing Record 23 of Set 3 | margaret river
# Processing Record 24 of Set 3 | san patricio
# Processing Record 25 of Set 3 | bilibino
# Processing Record 26 of Set 3 | vilyuysk
# Processing Record 27 of Set 3 | khamis mushait
# Processing Record 28 of Set 3 | ploneour-lanvern
# Processing Record 29 of Set 3 | fyodorovka
# Processing Record 30 of Set 3 | rongelap
# Processing Record 31 of Set 3 | kaset wisai
# Processing Record 32 of Set 3 | brzozow
# Processing Record 33 of Set 3 | atafu village
# Processing Record 34 of Set 3 | tura
# Processing Record 35 of Set 3 | galax
# Processing Record 36 of Set 3 | la cruz
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | southampton
# Processing Record 39 of Set 3 | yinchuan
# Processing Record 40 of Set 3 | champerico
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | wailua homesteads
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | phan rang-thap cham
# Processing Record 45 of Set 3 | arkhangel'sk
# Processing Record 46 of Set 3 | la passe
# Processing Record 47 of Set 3 | nar'yan-mar
# Processing Record 48 of Set 3 | val-des-monts
# Processing Record 49 of Set 3 | kirakira
# Processing Record 0 of Set 4 | guarapari
# Processing Record 1 of Set 4 | guerrero negro
# Processing Record 2 of Set 4 | tolanaro
# Processing Record 3 of Set 4 | zavetnoye
# Processing Record 4 of Set 4 | nizhniy kuranakh
# Processing Record 5 of Set 4 | babana
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | kalispell
# Processing Record 8 of Set 4 | east ballina
# Processing Record 9 of Set 4 | deland
# Processing Record 10 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 11 of Set 4 | mao
# Processing Record 12 of Set 4 | okhotsk
# Processing Record 13 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 4 | bria
# Processing Record 15 of Set 4 | bahir dar
# Processing Record 16 of Set 4 | mcminnville
# Processing Record 17 of Set 4 | kone
# Processing Record 18 of Set 4 | san antonio de pale
# Processing Record 19 of Set 4 | soto la marina
# Processing Record 20 of Set 4 | zangguy
# City not found. Skipping...
# Processing Record 21 of Set 4 | siguiri
# Processing Record 22 of Set 4 | arkalyk
# Processing Record 23 of Set 4 | traben-trarbach
# Processing Record 24 of Set 4 | olinda
# Processing Record 25 of Set 4 | nemuro
# Processing Record 26 of Set 4 | katima mulilo
# Processing Record 27 of Set 4 | james island
# City not found. Skipping...
# Processing Record 28 of Set 4 | punta arenas
# Processing Record 29 of Set 4 | as sulayyil
# Processing Record 30 of Set 4 | prince george
# Processing Record 31 of Set 4 | trondheim
# Processing Record 32 of Set 4 | loukhi
# Processing Record 33 of Set 4 | 'ain el melh
# Processing Record 34 of Set 4 | susuman
# Processing Record 35 of Set 4 | priozersk
# Processing Record 36 of Set 4 | conduaga
# Processing Record 37 of Set 4 | axim
# Processing Record 38 of Set 4 | vernon
# Processing Record 39 of Set 4 | mata-utu
# Processing Record 40 of Set 4 | portland
# Processing Record 41 of Set 4 | keflavik
# Processing Record 42 of Set 4 | pimenta bueno
# Processing Record 43 of Set 4 | uruzgan
# Processing Record 44 of Set 4 | isafjordur
# Processing Record 45 of Set 4 | garrucha
# Processing Record 46 of Set 4 | kununurra
# Processing Record 47 of Set 4 | minas de marcona
# Processing Record 48 of Set 4 | inhambane
# Processing Record 49 of Set 4 | saipan
# Processing Record 0 of Set 5 | gongzhuling
# Processing Record 1 of Set 5 | manfalut
# Processing Record 2 of Set 5 | usogorsk
# Processing Record 3 of Set 5 | merritt
# Processing Record 4 of Set 5 | ozu
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | aqadyr
# Processing Record 7 of Set 5 | shirwal
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | tabou
# Processing Record 10 of Set 5 | sisimiut
# Processing Record 11 of Set 5 | beyneu
# Processing Record 12 of Set 5 | sakaiminato
# Processing Record 13 of Set 5 | claveria
# Processing Record 14 of Set 5 | papao
# Processing Record 15 of Set 5 | herceg novi
# Processing Record 16 of Set 5 | hays
# Processing Record 17 of Set 5 | pematangsiantar
# Processing Record 18 of Set 5 | rafsanjan
# Processing Record 19 of Set 5 | sulak
# Processing Record 20 of Set 5 | panaba
# Processing Record 21 of Set 5 | afaahiti
# Processing Record 22 of Set 5 | happy valley-goose bay
# Processing Record 23 of Set 5 | sao vicente
# Processing Record 24 of Set 5 | udachny
# Processing Record 25 of Set 5 | murzuq
# Processing Record 26 of Set 5 | inarajan village
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | hawaiian paradise park
# Processing Record 29 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 30 of Set 5 | nadi
# Processing Record 31 of Set 5 | urayasu
# Processing Record 32 of Set 5 | al jawf
# Processing Record 33 of Set 5 | kitimat
# Processing Record 34 of Set 5 | xichang
# Processing Record 35 of Set 5 | lautoka
# Processing Record 36 of Set 5 | samfya
# Processing Record 37 of Set 5 | palmares do sul
# Processing Record 38 of Set 5 | utrik
# Processing Record 39 of Set 5 | malakal
# Processing Record 40 of Set 5 | nova sintra
# Processing Record 41 of Set 5 | ta`u
# Processing Record 42 of Set 5 | kingston
# Processing Record 43 of Set 5 | tidjikja
# Processing Record 44 of Set 5 | mabaruma
# Processing Record 45 of Set 5 | isla mujeres
# Processing Record 46 of Set 5 | cles
# Processing Record 47 of Set 5 | kirensk
# Processing Record 48 of Set 5 | wafangdian
# Processing Record 49 of Set 5 | saint-francois
# Processing Record 0 of Set 6 | veranopolis
# Processing Record 1 of Set 6 | naze
# Processing Record 2 of Set 6 | kharp
# Processing Record 3 of Set 6 | pyt-yakh
# Processing Record 4 of Set 6 | aleg
# Processing Record 5 of Set 6 | kerikeri
# Processing Record 6 of Set 6 | veydelevka
# Processing Record 7 of Set 6 | bamboo flat
# Processing Record 8 of Set 6 | ziro
# Processing Record 9 of Set 6 | burela de cabo
# Processing Record 10 of Set 6 | sandnessjoen
# Processing Record 11 of Set 6 | verdal
# Processing Record 12 of Set 6 | zouerate
# Processing Record 13 of Set 6 | lospalos
# Processing Record 14 of Set 6 | espargos
# City not found. Skipping...
# Processing Record 15 of Set 6 | kuqa
# Processing Record 16 of Set 6 | howrah
# Processing Record 17 of Set 6 | obo
# Processing Record 18 of Set 6 | smeeni
# Processing Record 19 of Set 6 | trenggalek
# Processing Record 20 of Set 6 | rajgarh
# Processing Record 21 of Set 6 | vadso
# Processing Record 22 of Set 6 | tashtagol
# Processing Record 23 of Set 6 | carnarvon
# Processing Record 24 of Set 6 | grand falls-windsor
# Processing Record 25 of Set 6 | camana
# Processing Record 26 of Set 6 | narvik
# Processing Record 27 of Set 6 | san luis de la loma
# Processing Record 28 of Set 6 | kota kinabalu
# Processing Record 29 of Set 6 | saint-philippe
# Processing Record 30 of Set 6 | ust-tsilma
# Processing Record 31 of Set 6 | brena alta
# Processing Record 32 of Set 6 | kawambwa
# Processing Record 33 of Set 6 | kenora
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 6 | pacific grove
# Processing Record 37 of Set 6 | huarmey
# Processing Record 38 of Set 6 | newman
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | nadym
# Processing Record 41 of Set 6 | thompson
# Processing Record 42 of Set 6 | zeya
# Processing Record 43 of Set 6 | heihe
# Processing Record 44 of Set 6 | chiroqchi
# Processing Record 45 of Set 6 | jogeva
# Processing Record 46 of Set 6 | ad dabbah
# Processing Record 47 of Set 6 | chifeng
# Processing Record 48 of Set 6 | nishinoomote
# Processing Record 49 of Set 6 | uturoa
# Processing Record 0 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 7 | sinabang
# Processing Record 2 of Set 7 | castuera
# Processing Record 3 of Set 7 | sodra sandby
# Processing Record 4 of Set 7 | guacamayas
# Processing Record 5 of Set 7 | twon-brass
# Processing Record 6 of Set 7 | nagqu
# Processing Record 7 of Set 7 | tamanrasset
# Processing Record 8 of Set 7 | gadzhiyevo
# Processing Record 9 of Set 7 | caiaponia
# Processing Record 10 of Set 7 | mossel bay
# Processing Record 11 of Set 7 | castillos
# Processing Record 12 of Set 7 | rumbek
# Processing Record 13 of Set 7 | puri
# Processing Record 14 of Set 7 | dolores
# Processing Record 15 of Set 7 | choibalsan
# Processing Record 16 of Set 7 | tarrafal
# Processing Record 17 of Set 7 | kodok
# City not found. Skipping...
# Processing Record 18 of Set 7 | yeonggwang
# Processing Record 19 of Set 7 | manokwari
# Processing Record 20 of Set 7 | mendoza
# Processing Record 21 of Set 7 | berezovo
# Processing Record 22 of Set 7 | north platte
# Processing Record 23 of Set 7 | marka
# Processing Record 24 of Set 7 | st. john's
# Processing Record 25 of Set 7 | jalingo
# Processing Record 26 of Set 7 | tossa de mar
# Processing Record 27 of Set 7 | isetskoye
# Processing Record 28 of Set 7 | kiunga
# Processing Record 29 of Set 7 | limulunga
# Processing Record 30 of Set 7 | port saint john's
# Processing Record 31 of Set 7 | weno
# Processing Record 32 of Set 7 | longquan
# Processing Record 33 of Set 7 | wodonga
# Processing Record 34 of Set 7 | kulgam
# Processing Record 35 of Set 7 | alofi
# Processing Record 36 of Set 7 | inonu
# Processing Record 37 of Set 7 | san luis rio colorado
# Processing Record 38 of Set 7 | arno
# Processing Record 39 of Set 7 | lazaro cardenas
# Processing Record 40 of Set 7 | tshabong
# Processing Record 41 of Set 7 | pindushi
# Processing Record 42 of Set 7 | grojec
# Processing Record 43 of Set 7 | vorgashor
# Processing Record 44 of Set 7 | filingue
# Processing Record 45 of Set 7 | port-vila
# Processing Record 46 of Set 7 | ambalangoda
# Processing Record 47 of Set 7 | micheweni
# Processing Record 48 of Set 7 | caister-on-sea
# Processing Record 49 of Set 7 | abaete
# Processing Record 0 of Set 8 | natal
# Processing Record 1 of Set 8 | amahai
# Processing Record 2 of Set 8 | luchegorsk
# Processing Record 3 of Set 8 | fort bragg
# Processing Record 4 of Set 8 | orsa
# Processing Record 5 of Set 8 | mar del plata
# Processing Record 6 of Set 8 | general acha
# Processing Record 7 of Set 8 | torghay
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | esmeralda
# Processing Record 10 of Set 8 | sao gabriel da cachoeira
# Processing Record 11 of Set 8 | ridder
# Processing Record 12 of Set 8 | xinyuan
# Processing Record 13 of Set 8 | khandyga
# Processing Record 14 of Set 8 | callao
# Processing Record 15 of Set 8 | timbuktu
# Processing Record 16 of Set 8 | tanout
# Processing Record 17 of Set 8 | masuda
# Processing Record 18 of Set 8 | lorengau
# Processing Record 19 of Set 8 | jaca
# Processing Record 20 of Set 8 | pitangueiras
# Processing Record 21 of Set 8 | zhengjiatun
# Processing Record 22 of Set 8 | vilhena
# Processing Record 23 of Set 8 | hotan
# Processing Record 24 of Set 8 | qaisumah
# Processing Record 25 of Set 8 | bovalino
# Processing Record 26 of Set 8 | dudinka
# Processing Record 27 of Set 8 | annaba
# Processing Record 28 of Set 8 | kulhudhuffushi
# Processing Record 29 of Set 8 | basse-terre
# Processing Record 30 of Set 8 | pont-l'abbe
# City not found. Skipping...
# Processing Record 31 of Set 8 | kimberley
# Processing Record 32 of Set 8 | skowhegan
# Processing Record 33 of Set 8 | atbasar
# Processing Record 34 of Set 8 | arraial do cabo
# Processing Record 35 of Set 8 | aral
# Processing Record 36 of Set 8 | kayangel
# Processing Record 37 of Set 8 | st. thomas
# Processing Record 38 of Set 8 | rio grande
# Processing Record 39 of Set 8 | sault ste. marie
# Processing Record 40 of Set 8 | sassandra
# Processing Record 41 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 42 of Set 8 | manakara
# Processing Record 43 of Set 8 | nuku'alofa
# Processing Record 44 of Set 8 | rembangan
# Processing Record 45 of Set 8 | tambura
# Processing Record 46 of Set 8 | demre
# Processing Record 47 of Set 8 | palangkaraya
# Processing Record 48 of Set 8 | brisas de zicatela
# Processing Record 49 of Set 8 | cable beach
# City not found. Skipping...
# Processing Record 0 of Set 9 | linghai
# Processing Record 1 of Set 9 | miahuatlan de porfirio diaz
# Processing Record 2 of Set 9 | peniche
# Processing Record 3 of Set 9 | mahenge
# Processing Record 4 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 5 of Set 9 | borgarnes
# Processing Record 6 of Set 9 | altai
# Processing Record 7 of Set 9 | chibougamau
# Processing Record 8 of Set 9 | port alfred
# Processing Record 9 of Set 9 | polyarnyy
# Processing Record 10 of Set 9 | amga
# Processing Record 11 of Set 9 | coyhaique
# Processing Record 12 of Set 9 | fuxin
# Processing Record 13 of Set 9 | querqueville
# Processing Record 14 of Set 9 | hasaki
# Processing Record 15 of Set 9 | caraballeda
# Processing Record 16 of Set 9 | larache
# Processing Record 17 of Set 9 | el limon
# Processing Record 18 of Set 9 | samraong
# Processing Record 19 of Set 9 | hulan
# Processing Record 20 of Set 9 | smara
# Processing Record 21 of Set 9 | mirzapur
# Processing Record 22 of Set 9 | prado
# Processing Record 23 of Set 9 | guichon
# Processing Record 24 of Set 9 | yankton
# Processing Record 25 of Set 9 | idaho falls
# Processing Record 26 of Set 9 | bulawayo
# Processing Record 27 of Set 9 | luau
# Processing Record 28 of Set 9 | piti village
# Processing Record 29 of Set 9 | kon tum
# Processing Record 30 of Set 9 | flying fish cove
# Processing Record 31 of Set 9 | port augusta
# Processing Record 32 of Set 9 | dejen
# Processing Record 33 of Set 9 | gaspe
# Processing Record 34 of Set 9 | ramgarh
# Processing Record 35 of Set 9 | howard springs
# Processing Record 36 of Set 9 | tianchang
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | lamar
# Processing Record 39 of Set 9 | kourou
# Processing Record 40 of Set 9 | ambon
# Processing Record 41 of Set 9 | darwin
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | aitape
# Processing Record 44 of Set 9 | mejit
# Processing Record 45 of Set 9 | chonchi
# Processing Record 46 of Set 9 | berriane
# Processing Record 47 of Set 9 | boyolangu
# Processing Record 48 of Set 9 | pocito
# Processing Record 49 of Set 9 | lethem
# Processing Record 0 of Set 10 | kupang
# Processing Record 1 of Set 10 | remire-montjoly
# Processing Record 2 of Set 10 | nueva gerona
# Processing Record 3 of Set 10 | mimoso do sul
# Processing Record 4 of Set 10 | copiapo
# Processing Record 5 of Set 10 | nuevo ideal
# Processing Record 6 of Set 10 | leninskoye
# Processing Record 7 of Set 10 | morioka
# Processing Record 8 of Set 10 | rio preto da eva
# Processing Record 9 of Set 10 | ofunato
# Processing Record 10 of Set 10 | timmins
# Processing Record 11 of Set 10 | lagoa
# Processing Record 12 of Set 10 | kodiak
# Processing Record 13 of Set 10 | sena madureira
# Processing Record 14 of Set 10 | lerwick
# Processing Record 15 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 16 of Set 10 | yekaterinoslavka
# Processing Record 17 of Set 10 | yuanping
# Processing Record 18 of Set 10 | oral
# Processing Record 19 of Set 10 | walvis bay
# Processing Record 20 of Set 10 | yakeshi
# Processing Record 21 of Set 10 | badagara
# Processing Record 22 of Set 10 | kushima
# Processing Record 23 of Set 10 | dingli
# Processing Record 24 of Set 10 | maceio
# Processing Record 25 of Set 10 | ribadesella
# Processing Record 26 of Set 10 | hoeyang
# Processing Record 27 of Set 10 | cinarli
# Processing Record 28 of Set 10 | livny
# Processing Record 29 of Set 10 | antsiranana
# Processing Record 30 of Set 10 | gorgan
# Processing Record 31 of Set 10 | sukumo
# Processing Record 32 of Set 10 | aasiaat
# Processing Record 33 of Set 10 | siwa oasis
# Processing Record 34 of Set 10 | sorong
# Processing Record 35 of Set 10 | jiuquan
# Processing Record 36 of Set 10 | kathwana
# City not found. Skipping...
# Processing Record 37 of Set 10 | parabel'
# Processing Record 38 of Set 10 | belfast
# Processing Record 39 of Set 10 | la palma
# Processing Record 40 of Set 10 | xiaoweizhai
# Processing Record 41 of Set 10 | dunedin
# Processing Record 42 of Set 10 | kalemie
# Processing Record 43 of Set 10 | severo-yeniseyskiy
# Processing Record 44 of Set 10 | kargat
# Processing Record 45 of Set 10 | korla
# Processing Record 46 of Set 10 | dzilam gonzalez
# Processing Record 47 of Set 10 | tralee
# Processing Record 48 of Set 10 | westport
# Processing Record 49 of Set 10 | daga
# Processing Record 0 of Set 11 | takeo
# Processing Record 1 of Set 11 | revda
# Processing Record 2 of Set 11 | baluntaicun
# City not found. Skipping...
# Processing Record 3 of Set 11 | qianzhou
# Processing Record 4 of Set 11 | yelizovo
# Processing Record 5 of Set 11 | chokwe
# Processing Record 6 of Set 11 | naha
# Processing Record 7 of Set 11 | ubari
# Processing Record 8 of Set 11 | robertsport
# Processing Record 9 of Set 11 | borba
# Processing Record 10 of Set 11 | al lagowa
# Processing Record 11 of Set 11 | corvallis
# Processing Record 12 of Set 11 | shingu
# Processing Record 13 of Set 11 | fauske
# Processing Record 14 of Set 11 | boshkengash
# Processing Record 15 of Set 11 | sao joao da barra
# Processing Record 16 of Set 11 | san pedro pochutla
# Processing Record 17 of Set 11 | la ronge
# Processing Record 18 of Set 11 | ouesso
# Processing Record 19 of Set 11 | nova vicosa
# Processing Record 20 of Set 11 | babu
# Processing Record 21 of Set 11 | kilju
# Processing Record 22 of Set 11 | santiago de cao
# Processing Record 23 of Set 11 | haparanda
# Processing Record 24 of Set 11 | san jose del cabo
# Processing Record 25 of Set 11 | tibu
# Processing Record 26 of Set 11 | cidreira
# Processing Record 27 of Set 11 | fale old settlement
# Processing Record 28 of Set 11 | la'ie
# Processing Record 29 of Set 11 | conception bay south
# Processing Record 30 of Set 11 | mahdia
# Processing Record 31 of Set 11 | srandakan
# Processing Record 32 of Set 11 | itaituba
# Processing Record 33 of Set 11 | quellon
# Processing Record 34 of Set 11 | katabu
# Processing Record 35 of Set 11 | g'uzor
# Processing Record 36 of Set 11 | nacala
# Processing Record 37 of Set 11 | yatou
# Processing Record 38 of Set 11 | tofol
# Processing Record 39 of Set 11 | codrington
# Processing Record 40 of Set 11 | kalmunai
# Processing Record 41 of Set 11 | makarska
# Processing Record 42 of Set 11 | box elder
# Processing Record 43 of Set 11 | nogliki
# Processing Record 44 of Set 11 | dzhambeyty
# Processing Record 45 of Set 11 | illizi
# Processing Record 46 of Set 11 | ghat
# Processing Record 47 of Set 11 | ramapuram
# Processing Record 48 of Set 11 | akureyri
# Processing Record 49 of Set 11 | tutoia
# Processing Record 0 of Set 12 | ar rass
# Processing Record 1 of Set 12 | korsakov
# Processing Record 2 of Set 12 | jaisalmer
# Processing Record 3 of Set 12 | dalandzadgad
# Processing Record 4 of Set 12 | kolonia
# Processing Record 5 of Set 12 | kroya
# Processing Record 6 of Set 12 | gerash
# Processing Record 7 of Set 12 | mount pearl
# Processing Record 8 of Set 12 | baotou
# Processing Record 9 of Set 12 | costa teguise
# City not found. Skipping...
# Processing Record 10 of Set 12 | qorveh
# Processing Record 11 of Set 12 | ola
# Processing Record 12 of Set 12 | north bend
# Processing Record 13 of Set 12 | weiser
# Processing Record 14 of Set 12 | arica
# Processing Record 15 of Set 12 | arteche
# Processing Record 16 of Set 12 | keningau
# Processing Record 17 of Set 12 | fristad
# Processing Record 18 of Set 12 | malango
# Processing Record 19 of Set 12 | bangkalan
# Processing Record 20 of Set 12 | general roca
# Processing Record 21 of Set 12 | manicore
# Processing Record 22 of Set 12 | richards bay
# Processing Record 23 of Set 12 | margate
# Processing Record 24 of Set 12 | yanchep
# Processing Record 25 of Set 12 | kafin hausa
# Processing Record 26 of Set 12 | kuraymah
# Processing Record 27 of Set 12 | punata
# Processing Record 28 of Set 12 | jean-rabel
# Processing Record 29 of Set 12 | menaka
# Processing Record 30 of Set 12 | center
# Processing Record 31 of Set 12 | sai buri
# Processing Record 32 of Set 12 | ilebo
# Processing Record 33 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 34 of Set 12 | renigunta
# Processing Record 35 of Set 12 | nabire
# Processing Record 36 of Set 12 | lubango
# Processing Record 37 of Set 12 | tazacorte
# Processing Record 38 of Set 12 | tavsanli
# Processing Record 39 of Set 12 | valparaiso
# Processing Record 40 of Set 12 | sterling
# Processing Record 41 of Set 12 | bushehr
# Processing Record 42 of Set 12 | yanam
# Processing Record 43 of Set 12 | wagini
# Processing Record 44 of Set 12 | melilla
# Processing Record 45 of Set 12 | tanjung sepat
# Processing Record 46 of Set 12 | pathein
# Processing Record 47 of Set 12 | oxelosund
# Processing Record 48 of Set 12 | forbes
# Processing Record 49 of Set 12 | alexandria
# Processing Record 0 of Set 13 | manacapuru
# Processing Record 1 of Set 13 | kili
# Processing Record 2 of Set 13 | sumbe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      port mathurin -19.6833  63.4167     23.37        62           2
# 1           kargasok  59.0556  80.8572     13.95        71          14
# 2         constantia  44.1833  28.6500     20.39        80          83
# 3           meulaboh   4.1363  96.1285     24.13        90          34
# 4  port-aux-francais -49.3500  70.2167      3.42        68          36
#
#    Wind Speed Country        Date
# 0       10.51      MU  1688414923
# 1        2.61      RU  1688414924
# 2        3.25      RO  1688414925
# 3        1.76      ID  1688414926
# 4       16.30      TF  1688414926

# %%
# Export the City_Data into a csv

city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            port mathurin -19.6833  63.4167     23.37        62           2
# 1                 kargasok  59.0556  80.8572     13.95        71          14
# 2               constantia  44.1833  28.6500     20.39        80          83
# 3                 meulaboh   4.1363  96.1285     24.13        90          34
# 4        port-aux-francais -49.3500  70.2167      3.42        68          36
#
#          Wind Speed Country        Date
# City_ID
# 0             10.51      MU  1688414923
# 1              2.61      RU  1688414924
# 2              3.25      RO  1688414925
# 3              1.76      ID  1688414926
# 4             16.30      TF  1688414926

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", alpha=0.75)

# Set the title and labels
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", alpha=0.75)

# Set the title and labels
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", alpha=0.75)

# Set the title and labels
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, title, output_path):
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

    # Create regression line
    regression_line = x_values * slope + intercept

    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolor="black", alpha=0.75)

    # Plot the regression line
    plt.plot(x_values, regression_line, color="red")

    # Set the title and labels
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Add the regression equation to the plot
    equation = f"y = {slope:.2f}x + {intercept:.2f}"
    plt.annotate(equation, (min(x_values), max(y_values)), fontsize=12, color="red")

    # Display the correlation coefficient on the plot
    correlation = f"Correlation: {rvalue:.2f}"
    plt.annotate(correlation, (min(x_values), max(y_values) - 5), fontsize=12, color="red")

    # Save the figure
    plt.savefig(output_path)

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# Filter the city_data_df to get the Northern Hemisphere data
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           kargasok  59.0556   80.8572     13.95        71          14
# 2         constantia  44.1833   28.6500     20.39        80          83
# 3           meulaboh   4.1363   96.1285     24.13        90          34
# 7        yellowknife  62.4560 -114.3525     19.29        32          20
# 8              kidal  18.4411    1.4078     33.62        28          58
#
#          Wind Speed Country        Date
# City_ID
# 1              2.61      RU  1688414924
# 2              3.25      RO  1688414925
# 3              1.76      ID  1688414926
# 7              5.66      CA  1688414730
# 8              9.09      ML  1688414927

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# Filter the city_data_df to get the Southern Hemisphere data
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            port mathurin -19.6833   63.4167     23.37        62           2
# 4        port-aux-francais -49.3500   70.2167      3.42        68          36
# 5                  ushuaia -54.8000  -68.3000      4.81        65          20
# 6                adamstown -25.0660 -130.1015     20.69        64           0
# 9            blackmans bay -43.0167  147.3167      4.18        92         100
#
#          Wind Speed Country        Date
# City_ID
# 0             10.51      MU  1688414923
# 4             16.30      TF  1688414926
# 5              2.06      AR  1688414926
# 6              4.25      PN  1688414927
# 9              1.12      AU  1688414927

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Define a function to create linear regression and scatter plot
def plot_linear_regression(x_values, y_values, y_label, text_coordinates, hemisphere_title):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept

    # Create the equation of the line
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

    # Create the scatter plot and linear regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")

    # Annotate the line equation
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")

    # Set labels and title
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.title(f"{hemisphere_title} Linear Regression: Latitude vs. {y_label}")

    # Print the r-squared value
    print(f"The r-squared is: {rvalue**2}")

    # Show the plot
    plt.show()

# %%
# Build the scatter plots for temperature vs. latitude in both hemispheres
# Northern Hemisphere
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.title("City Latitude vs. Max Temperature (Northern Hemisphere)")
plt.grid(True)

# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Max Temperature (°C)", (0, 0), "Northern Hemisphere")


# Show plot
plt.show()
# Out:
# The r-squared is: 0.41599508258761775

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (Northern Hemisphere)")
plt.grid(True)

# Perform linear regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Humidity (%)", (40,10), "Northern Hemisphere")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.0009007565178955524

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (Southern Hemisphere)")
plt.grid(True)

# Perform linear regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Humidity (%)", (-50,20), "Southern Hemisphere")

# Show plot
plt.show()
# Out:
# The r-squared is: 3.809686126516374e-05

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (Northern Hemisphere)")
plt.grid(True)

# Perform linear regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Cloudiness (%)", (10,50), "Northern Hemisphere")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.0048084083149676805

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (Southern Hemisphere)")
plt.grid(True)

# Perform linear regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Cloudiness (%)", (-50,50), "Southern Hemisphere")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.001978800380876356

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (Northern Hemisphere)")
plt.grid(True)

# Perform linear regression
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Wind Speed (m/s)", (10, 20), "Northern Hemisphere")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.0009095920962588304

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], marker="o", edgecolor="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (Southern Hemisphere)")
plt.grid(True)

# Perform linear regression
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Wind Speed (m/s)", (-50, 8), "Southern Hemisphere")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.056880775639402206

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
